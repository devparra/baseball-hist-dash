# %%
import csv
import pandas as pd
import numpy as np

# %%
baseball_df = pd.read_csv('team.csv')

# %%
baseball_df.head()
# Out:
#    year league_id team_id  rank    g   w   l div_win wc_win lg_win  ... sv  \
# 0  1903        AL     BOS     1  141  91  47     NaN    NaN      Y  ...  4
# 1  1903        NL     BRO     5  139  70  66     NaN    NaN      N  ...  4
# 2  1903        NL     BSN     6  140  58  80     NaN    NaN      N  ...  1
# 3  1903        AL     CHA     7  138  60  77     NaN    NaN      N  ...  4
# 4  1903        NL     CHN     3  139  82  56     NaN    NaN      N  ...  6
#
#      ha  hra  bba  soa    e  dp    fp               name  \
# 0  1142   23  269  579  235  86  0.95   Boston Americans
# 1  1276   18  377  438  284  98  0.95  Brooklyn Superbas
# 2  1310   30  460  516  351  89  0.93  Boston Beaneaters
# 3  1233   23  287  391  297  85  0.94  Chicago White Sox
# 4  1182   14  354  451  314  78  0.94       Chicago Cubs
#
#                         park
# 0  Huntington Avenue Grounds
# 1        Washington Park III
# 2      South End Grounds III
# 3         South Side Park II
# ...

# %%
baseball_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2390 entries, 0 to 2389
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       2390 non-null   int64
#  1   league_id  2390 non-null   object
#  2   team_id    2390 non-null   object
#  3   rank       2390 non-null   int64
#  4   g          2390 non-null   int64
#  5   w          2390 non-null   int64
#  6   l          2390 non-null   int64
#  7   div_win    1260 non-null   object
#  8   wc_win     624 non-null    object
#  9   lg_win     2362 non-null   object
#  10  ws_win     2330 non-null   object
#  11  r          2390 non-null   int64
#  12  ab         2390 non-null   int64
#  13  h          2390 non-null   int64
#  14  double     2390 non-null   int64
#  15  triple     2390 non-null   int64
#  16  hr         2390 non-null   int64
#  17  bb         2390 non-null   int64
#  18  so         2270 non-null   float64
# ...

# %%
filter = baseball_df[baseball_df.name == 'Chicago Cubs'].drop('team_id',axis=1)
filter.head()
# Out:
#     year league_id  rank    g    w   l div_win wc_win lg_win ws_win  ...  sv  \
# 4   1903        NL     3  139   82  56     NaN    NaN      N      N  ...   6
# 20  1904        NL     2  156   93  60     NaN    NaN      N    NaN  ...   6
# 36  1905        NL     3  155   92  61     NaN    NaN      N      N  ...   2
# 52  1906        NL     1  155  116  36     NaN    NaN      Y      N  ...  10
# 68  1907        NL     1  155  107  45     NaN    NaN      Y      Y  ...   8
#
#       ha  hra  bba  soa    e   dp    fp          name               park
# 4   1182   14  354  451  314   78  0.94  Chicago Cubs  West Side Park II
# 20  1150   16  402  618  282   89  0.95  Chicago Cubs  West Side Park II
# 36  1135   14  385  627  246   99  0.96  Chicago Cubs  West Side Park II
# 52  1018   12  446  702  190  100  0.97  Chicago Cubs  West Side Park II
# 68  1054   11  402  586  211  110  0.96  Chicago Cubs  West Side Park II
#
# [5 rows x 33 columns]

# %%
filter.plot.bar(x='year',y=['w','l'],rot=100)

# %%
year_df = filter.set_index('year')
year_df.head()
# Out:
#      league_id  rank    g    w   l div_win wc_win lg_win ws_win    r  ...  sv  \
# year                                                                  ...
# 1903        NL     3  139   82  56     NaN    NaN      N      N  695  ...   6
# 1904        NL     2  156   93  60     NaN    NaN      N    NaN  599  ...   6
# 1905        NL     3  155   92  61     NaN    NaN      N      N  667  ...   2
# 1906        NL     1  155  116  36     NaN    NaN      Y      N  705  ...  10
# 1907        NL     1  155  107  45     NaN    NaN      Y      Y  574  ...   8
#
#         ha  hra  bba  soa    e   dp    fp          name               park
# year
# 1903  1182   14  354  451  314   78  0.94  Chicago Cubs  West Side Park II
# 1904  1150   16  402  618  282   89  0.95  Chicago Cubs  West Side Park II
# 1905  1135   14  385  627  246   99  0.96  Chicago Cubs  West Side Park II
# 1906  1018   12  446  702  190  100  0.97  Chicago Cubs  West Side Park II
# ...

# %%
teams = baseball_df['name'].unique()
# Dictionary of options for Dropdown menu
team_dic={}
team_dic_list=[]
for i in range(len(teams)):
    team_dic['label'] = teams[i]
    team_dic['value'] = teams[i]
    team_dic_list.append(team_dic.copy())

# %%
print(team_dic_list)
# Out:
# [{'label': 'Boston Americans', 'value': 'Boston Americans'}, {'label': 'Brooklyn Superbas', 'value': 'Brooklyn Superbas'}, {'label': 'Boston Beaneaters', 'value': 'Boston Beaneaters'}, {'label': 'Chicago White Sox', 'value': 'Chicago White Sox'}, {'label': 'Chicago Cubs', 'value': 'Chicago Cubs'}, {'label': 'Cincinnati Reds', 'value': 'Cincinnati Reds'}, {'label': 'Cleveland Naps', 'value': 'Cleveland Naps'}, {'label': 'Detroit Tigers', 'value': 'Detroit Tigers'}, {'label': 'New York Giants', 'value': 'New York Giants'}, {'label': 'New York Highlanders', 'value': 'New York Highlanders'}, {'label': 'Philadelphia Athletics', 'value': 'Philadelphia Athletics'}, {'label': 'Philadelphia Phillies', 'value': 'Philadelphia Phillies'}, {'label': 'Pittsburgh Pirates', 'value': 'Pittsburgh Pirates'}, {'label': 'St. Louis Browns', 'value': 'St. Louis Browns'}, {'label': 'St. Louis Cardinals', 'value': 'St. Louis Cardinals'}, {'label': 'Washington Senators', 'value': 'Washington Senators'}, {'lab
# ...

# %%
def listpair(new):
    _dic={}
    _dic_list=[]
    for i in range(len(new)):
        _dic['label'] = new[i]
        _dic['value'] = new[i]
        _dic_list.append(_dic.copy())
    return _dic_list

# Broken, needs to put out range instead of complete list
def dynamicteam(new):
    teams = baseball_df[['year','name']]
    for i in range(len(new)):
        filter_year = baseball_df[baseball_df.year <= new[i]['value'][1]]
        filter_year = filter_year[filter_year.year >= new[i]['value'][0]]
    filter_team = filter_year.name.unique()
    team_list = listpair(filter_team)
    return team_list


# list of teams and years
year_era = [{'label': 'Dead Ball','value': (1903,1919)},{'label': 'Live Ball','value': (1920,1941)},{'label': 'Integration','value': (1942,1960)},{'label': 'Expantion','value': (1961,1976)},{'label': 'Free Agency','value': (1977,1993)},{'label': 'Steroid','value': (1994,2005)},{'l abel': 'Post-Steroid','value': (2006,2015)}]

# for i in range(len(year_era)):
#     filter_year = baseball_df[baseball_df.year <= year_era[i]['value'][1]]
#     filter_year = filter_year[filter_year.year >= year_era[i]['value'][0]]
#     print(filter_year)

new_era = dynamicteam(year_era)

new_era
# baseball_df[baseball_df.year <= 1919]['name'].unique()
# Out:
# [{'label': 'Arizona Diamondbacks', 'value': 'Arizona Diamondbacks'},
#  {'label': 'Atlanta Braves', 'value': 'Atlanta Braves'},
#  {'label': 'Baltimore Orioles', 'value': 'Baltimore Orioles'},
#  {'label': 'Boston Red Sox', 'value': 'Boston Red Sox'},
#  {'label': 'Chicago White Sox', 'value': 'Chicago White Sox'},
#  {'label': 'Chicago Cubs', 'value': 'Chicago Cubs'},
#  {'label': 'Cincinnati Reds', 'value': 'Cincinnati Reds'},
#  {'label': 'Cleveland Indians', 'value': 'Cleveland Indians'},
#  {'label': 'Colorado Rockies', 'value': 'Colorado Rockies'},
#  {'label': 'Detroit Tigers', 'value': 'Detroit Tigers'},
#  {'label': 'Florida Marlins', 'value': 'Florida Marlins'},
#  {'label': 'Houston Astros', 'value': 'Houston Astros'},
#  {'label': 'Kansas City Royals', 'value': 'Kansas City Royals'},
#  {'label': 'Los Angeles Angels of Anaheim',
#   'value': 'Los Angeles Angels of Anaheim'},
#  {'label': 'Los Angeles Dodgers', 'value': 'Los Angeles Dodgers'},
# ...

# %%
def dynamicera(new,x):
    team_names = baseball_df[['year','name']]
    filter_year = team_names[team_names.year <= new[x][1]]
    filter_year = filter_year[filter_year.year >= new[x][0]]
    filter_team = filter_year['name'].unique()
    return filter_team

era_list = ['Dead Ball','Live Ball','Integration','Expantion','Free Agency','Steroid','Post-Steroid']
time_list = [(1903,1919),(1920,1941),(1942,1960),(1961,1976),(1977,1993),(1994,2005),(2005,2015)]
teamname = dynamicera(time_list,2)
teamname
# Out:
# array(['Boston Red Sox', 'Brooklyn Dodgers', 'Boston Braves',
#        'Chicago White Sox', 'Chicago Cubs', 'Cincinnati Reds',
#        'Cleveland Indians', 'Detroit Tigers', 'New York Giants',
#        'New York Yankees', 'Philadelphia Athletics',
#        'Philadelphia Phillies', 'Pittsburgh Pirates', 'St. Louis Browns',
#        'St. Louis Cardinals', 'Washington Senators',
#        'Philadelphia Blue Jays', 'Milwaukee Braves', 'Baltimore Orioles',
#        'Cincinnati Redlegs', 'Kansas City Athletics',
#        'Los Angeles Dodgers', 'San Francisco Giants'], dtype=object)

# %%
def listpair(new):
    _dict={}
    _dict_list=[]
    for i in range(len(new)):
        _dict['label'] = new[i]
        _dict['value'] = new[i]
        _dict_list.append(_dict.copy())
    return _dict_list


def dynamicera(new,x):
    team_names = baseball_df[['year','name']]
    filter_year = team_names[team_names.year <= new[x][1]]
    filter_year = filter_year[filter_year.year >= new[x][0]]
    filter_team = filter_year['name'].unique()
    return listpair(filter_team)


era_list = [{'label': 'Dead Ball','value': 'Dead Ball'},{'label': 'Live Ball','value': 'Live Ball'},{'label': 'Integration','value': 'Integration'},{'label': 'Expantion','value': 'Expantion'},{'label': 'Free Agency','value': 'Free Agency'},{'label': 'Steroid','value': 'Steroid'},{'label': 'Post-Steroid','value': 'Post-Steroid'}]
time_list = [(1903,1919),(1920,1941),(1942,1960),(1961,1976),(1977,1993),(1994,2005),(2005,2015)]
era_teams = dynamicera(time_list,0)
era_teams
# Out:
# [{'label': 'Boston Americans', 'value': 'Boston Americans'},
#  {'label': 'Brooklyn Superbas', 'value': 'Brooklyn Superbas'},
#  {'label': 'Boston Beaneaters', 'value': 'Boston Beaneaters'},
#  {'label': 'Chicago White Sox', 'value': 'Chicago White Sox'},
#  {'label': 'Chicago Cubs', 'value': 'Chicago Cubs'},
#  {'label': 'Cincinnati Reds', 'value': 'Cincinnati Reds'},
#  {'label': 'Cleveland Naps', 'value': 'Cleveland Naps'},
#  {'label': 'Detroit Tigers', 'value': 'Detroit Tigers'},
#  {'label': 'New York Giants', 'value': 'New York Giants'},
#  {'label': 'New York Highlanders', 'value': 'New York Highlanders'},
#  {'label': 'Philadelphia Athletics', 'value': 'Philadelphia Athletics'},
#  {'label': 'Philadelphia Phillies', 'value': 'Philadelphia Phillies'},
#  {'label': 'Pittsburgh Pirates', 'value': 'Pittsburgh Pirates'},
#  {'label': 'St. Louis Browns', 'value': 'St. Louis Browns'},
#  {'label': 'St. Louis Cardinals', 'value': 'St. Louis Cardinals'},
# ...

# %%
filter_year = baseball_df[baseball_df.year == 1927]
filter_year.head()
# Out:
#      year league_id team_id  rank    g   w    l div_win wc_win lg_win  ...  \
# 400  1927        AL     BOS     8  154  51  103     NaN    NaN      N  ...
# 401  1927        NL     BRO     6  154  65   88     NaN    NaN      N  ...
# 402  1927        NL     BSN     7  155  60   94     NaN    NaN      N  ...
# 403  1927        AL     CHA     5  153  70   83     NaN    NaN      N  ...
# 404  1927        NL     CHN     4  153  85   68     NaN    NaN      N  ...
#
#      sv    ha  hra  bba  soa    e   dp    fp               name           park
# 400   7  1603   56  558  381  222  162  0.96     Boston Red Sox  Fenway Park I
# 401  10  1382   63  418  574  226  117  0.96    Brooklyn Robins   Ebbets Field
# 402  11  1602   43  468  402  231  130  0.96      Boston Braves   Braves Field
# 403   8  1467   55  440  365  180  131  0.97  Chicago White Sox  Comiskey Park
# 404   5  1439   50  514  465  181  152  0.97       Chicago Cubs  Wrigley Field
#
# [5 rows x 34 columns]

# %%
filter_year[filter_year.name == 'Chicago Cubs']['team_id']
# Out:
# 404    CHN
# Name: team_id, dtype: object

# %%
man_df = pd.read_csv('manager.csv')

# %%
man_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3405 entries, 0 to 3404
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  3405 non-null   object
#  1   year       3405 non-null   int64
#  2   team_id    3405 non-null   object
#  3   league_id  3338 non-null   object
#  4   inseason   3405 non-null   int64
#  5   g          3405 non-null   int64
#  6   w          3405 non-null   int64
#  7   l          3405 non-null   int64
#  8   rank       3404 non-null   float64
#  9   plyr_mgr   3405 non-null   object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 266.1+ KB

# %%
man_df.head()
# Out:
#    player_id  year team_id league_id  inseason   g   w   l  rank plyr_mgr
# 0  wrighha01  1871     BS1       NaN         1  31  20  10   3.0        Y
# 1   woodji01  1871     CH1       NaN         1  28  19   9   2.0        Y
# 2  paborch01  1871     CL1       NaN         1  29  10  19   8.0        Y
# 3  lennobi01  1871     FW1       NaN         1  14   5   9   8.0        Y
# 4  deaneha01  1871     FW1       NaN         2   5   2   3   8.0        Y

# %%
man_df[man_df.year == 1927][man_df.team_id == 'CHN'].set_index('year')
# Out:
# <ipython-input-16-bbaad5c4efc3>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   man_df[man_df.year == 1927][man_df.team_id == 'CHN'].set_index('year')
#       player_id team_id league_id  inseason    g   w   l  rank plyr_mgr
# year
# 1927  mccarjo99     CHN        NL         1  153  85  68   4.0        N

# %%
player_df = pd.read_csv('player.csv')

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18846 entries, 0 to 18845
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   player_id      18846 non-null  object
#  1   birth_year     18703 non-null  float64
#  2   birth_month    18531 non-null  float64
#  3   birth_day      18382 non-null  float64
#  4   birth_country  18773 non-null  object
#  5   birth_state    18220 non-null  object
#  6   birth_city     18647 non-null  object
#  7   death_year     9336 non-null   float64
#  8   death_month    9335 non-null   float64
#  9   death_day      9334 non-null   float64
#  10  death_country  9329 non-null   object
#  11  death_state    9277 non-null   object
#  12  death_city     9325 non-null   object
#  13  name_first     18807 non-null  object
#  14  name_last      18846 non-null  object
#  15  name_given     18807 non-null  object
#  16  weight         17975 non-null  float64
# ...

# %%
pitcher_df = pd.read_csv('pitching.csv')

# %%
pitcher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44139 entries, 0 to 44138
# Data columns (total 30 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  44139 non-null  object
#  1   year       44139 non-null  int64
#  2   stint      44139 non-null  int64
#  3   team_id    44139 non-null  object
#  4   league_id  44008 non-null  object
#  5   w          44139 non-null  int64
#  6   l          44139 non-null  int64
#  7   g          44139 non-null  int64
#  8   gs         44139 non-null  int64
#  9   cg         44139 non-null  int64
#  10  sho        44139 non-null  int64
#  11  sv         44139 non-null  int64
#  12  ipouts     44138 non-null  float64
#  13  h          44139 non-null  int64
#  14  er         44139 non-null  int64
#  15  hr         44139 non-null  int64
#  16  bb         44139 non-null  int64
#  17  so         44139 non-null  int64
#  18  baopp      42614 non-null  float64
# ...

# %%
pitcher_df[pitcher_df.year == 1927][pitcher_df.team_id == 'CHN'].set_index('year')
# Out:
# <ipython-input-21-a813f63a125b>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pitcher_df[pitcher_df.year == 1927][pitcher_df.team_id == 'CHN'].set_index('year')
#       player_id  stint team_id league_id   w   l   g  gs  cg  sho  ...  ibb  \
# year                                                               ...
# 1927  blakesh01      1     CHN        NL  13  14  32  27  13    2  ...  NaN
# 1927  brillji01      1     CHN        NL   4   2  32  12   4    0  ...  NaN
# 1927   bushgu01      1     CHN        NL  10  10  36  22   9    1  ...  NaN
# 1927  carlsha01      2     CHN        NL  12   8  27  22  15    2  ...  NaN
# 1927   deanwa01      2     CHN        NL   0   0   2   0   0    0  ...  NaN
# 1927  grampha01      1     CHN        NL   0   0   2   0   0    0  ...  NaN
# 1927  jonespe01      1     CHN        NL   7   8  30  11   5    1  ...  NaN
# 1927  kaufmto01      1     CHN        NL   3   3   9   6   3    0  ...  NaN
# ...

# %%
player_df[player_df.player_id == 'blakesh01']
# Out:
#       player_id  birth_year  birth_month  birth_day birth_country birth_state  \
# 1382  blakesh01      1899.0          9.0       17.0           USA          WV
#
#      birth_city  death_year  death_month  death_day  ... name_last  \
# 1382     Ansted      1982.0         10.0       31.0  ...     Blake
#
#           name_given weight height bats throws       debut  final_game  \
# 1382  John Frederick  180.0   72.0    B      R  1920-06-29  1937-09-26
#
#       retro_id   bbref_id
# 1382  blaks101  blakesh01
#
# [1 rows x 24 columns]
